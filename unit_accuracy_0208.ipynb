# %%
import os

import numpy as np
import pandas as  pd
import matplotlib.pyplot as plt
import gd_parameters as gd
import pickle
import bdpy

from gd_features import Features
from itertools import product
from bdpy.stats import corrcoef
from time import time

# %%
# get parameters from gd_features
data_dir = gd.data_dir
subject_list = gd.subject_list
roi_list = gd.roi_list
feature_file = gd.feature_file
feature_type = gd.feature_type
result_dir = gd.result_dir
feature_file = gd.feature_file
feature_type = gd.feature_type
result_dir = gd.result_dir
features = Features(os.path.join(data_dir, feature_file), feature_type)

# %%
# set data dict
acc_result = {}
for sbj in subject_list:
    acc_result[sbj] = {}
    for roi in roi_list:
        acc_result[sbj][roi] = {}
        for feat in features.layers:
            acc_result[sbj][roi][feat] = {}

# compute accuracy
for sbj, roi, feat in product(subject_list, roi_list, features.layers):
    
    start_time = time()

    analysis_id = '%s-%s-%s' % (sbj, roi, feat)
    print 'Analysis %s' % analysis_id

    ## Load feature prediction results for each unit
    result_unit_file = os.path.join(result_dir, sbj, roi, feat + '.pkl')
    with open(result_unit_file, 'rb') as f:
        
        results_unit = pickle.load(f)

    ## Preparing data (image features)
    feature = features.get('value', feat)
    feature_type = features.get('type')
    feature_catlabel = features.get('category_label')

    ## Calculate image and category feature prediction accuracy

    ## Aggregate all units prediction (num_sample * num_unit)
    pred_percept = np.vstack(results_unit['predict_percept_catave']).T
    pred_imagery = np.vstack(results_unit['predict_imagery_catave']).T
    
    cat_percept = results_unit['category_test_percept'][0]
    cat_imagery = results_unit['category_test_imagery'][0]

    ind_imgtest = feature_type == 2
    ind_cattest = feature_type == 3

    test_feat_img = bdpy.get_refdata(feature[ind_imgtest, :],
                                     feature_catlabel[ind_imgtest],
                                     cat_percept);
    test_feat_cat_percept = bdpy.get_refdata(feature[ind_cattest, :],
                                             feature_catlabel[ind_cattest],
                                             cat_percept)
    test_feat_cat_imagery = bdpy.get_refdata(feature[ind_cattest, ],
                                             feature_catlabel[ind_cattest],
                                                     cat_imagery)

    ## Get image and category feature prediction accuracy
    predacc_image_percept = corrcoef(pred_percept, test_feat_img, var='col')
    predacc_category_percept = corrcoef(pred_percept, test_feat_cat_percept, var='col')
    predacc_category_imagery = corrcoef(pred_imagery, test_feat_cat_imagery, var='col')
    
    acc_result[sbj][roi][feat]["predacc_image_percept"] = predacc_image_percept
    acc_result[sbj][roi][feat]["predacc_category_percept"] = predacc_category_percept
    acc_result[sbj][roi][feat]["predacc_category_imagery"] = predacc_category_imagery
# Out:
# Analysis Subject1-V1-conv1
# Analysis Subject1-V1-conv2
# Analysis Subject1-V1-conv3
# Analysis Subject1-V1-conv4
# Analysis Subject1-V1-conv5
# Analysis Subject1-V1-fc6-conv
# Analysis Subject1-V1-fc7-conv
# Analysis Subject1-V1-fc8-conv
# Analysis Subject1-V2-conv1
# Analysis Subject1-V2-conv2
# Analysis Subject1-V2-conv3
# Analysis Subject1-V2-conv4
# Analysis Subject1-V2-conv5
# Analysis Subject1-V2-fc6-conv
# Analysis Subject1-V2-fc7-conv
# Analysis Subject1-V2-fc8-conv
# Analysis Subject1-V3-conv1
# Analysis Subject1-V3-conv2
# Analysis Subject1-V3-conv3
# Analysis Subject1-V3-conv4
# Analysis Subject1-V3-conv5
# Analysis Subject1-V3-fc6-conv
# Analysis Subject1-V3-fc7-conv
# Analysis Subject1-V3-fc8-conv
# Analysis Subject1-V4-conv1
# Analysis Subject1-V4-conv2
# Analysis Subject1-V4-conv3
# Analysis Subject1-V4-conv4
# Analysis Subject1-V4-conv5
# Analysis Subject1-V4-fc6-conv
# Analysis Subject1-V4-fc7-conv
# Analysis Subject1-V4-fc8-conv
# Analysis Subject1-LOC-conv1
# Analysis Subject1-LOC-conv2
# Analysis Subject1-LOC-conv3
# Analysis Subject1-LOC-conv4
# Analysis Subject1-LOC-conv5
# Analysis Subject1-LOC-fc6-conv
# Analysis Subject1-LOC-fc7-conv
# Analysis Subject1-LOC-fc8-conv
# Analysis Subject1-FFA-conv1
# Analysis Subject1-FFA-conv2
# Analysis Subject1-FFA-conv3
# Analysis Subject1-FFA-conv4
# Analysis Subject1-FFA-conv5
# Analysis Subject1-FFA-fc6-conv
# Analysis Subject1-FFA-fc7-conv
# Analysis Subject1-FFA-fc8-conv
# Analysis Subject1-PPA-conv1
# Analysis Subject1-PPA-conv2
# Analysis Subject1-PPA-conv3
# Analysis Subject1-PPA-conv4
# Analysis Subject1-PPA-conv5
# Analysis Subject1-PPA-fc6-conv
# Analysis Subject1-PPA-fc7-conv
# Analysis Subject1-PPA-fc8-conv
# Analysis Subject1-LVC-conv1
# Analysis Subject1-LVC-conv2
# Analysis Subject1-LVC-conv3
# Analysis Subject1-LVC-conv4
# Analysis Subject1-LVC-conv5
# Analysis Subject1-LVC-fc6-conv
# Analysis Subject1-LVC-fc7-conv
# Analysis Subject1-LVC-fc8-conv
# Analysis Subject1-HVC-conv1
# Analysis Subject1-HVC-conv2
# Analysis Subject1-HVC-conv3
# Analysis Subject1-HVC-conv4
# Analysis Subject1-HVC-conv5
# Analysis Subject1-HVC-fc6-conv
# Analysis Subject1-HVC-fc7-conv
# Analysis Subject1-HVC-fc8-conv
# Analysis Subject1-VC-conv1
# Analysis Subject1-VC-conv2
# Analysis Subject1-VC-conv3
# Analysis Subject1-VC-conv4
# Analysis Subject1-VC-conv5
# Analysis Subject1-VC-fc6-conv
# Analysis Subject1-VC-fc7-conv
# Analysis Subject1-VC-fc8-conv
# Analysis Subject2-V1-conv1
# Analysis Subject2-V1-conv2
# Analysis Subject2-V1-conv3
# Analysis Subject2-V1-conv4
# Analysis Subject2-V1-conv5
# Analysis Subject2-V1-fc6-conv
# Analysis Subject2-V1-fc7-conv
# Analysis Subject2-V1-fc8-conv
# Analysis Subject2-V2-conv1
# Analysis Subject2-V2-conv2
# Analysis Subject2-V2-conv3
# Analysis Subject2-V2-conv4
# Analysis Subject2-V2-conv5
# Analysis Subject2-V2-fc6-conv
# Analysis Subject2-V2-fc7-conv
# Analysis Subject2-V2-fc8-conv
# Analysis Subject2-V3-conv1
# Analysis Subject2-V3-conv2
# Analysis Subject2-V3-conv3
# Analysis Subject2-V3-conv4
# Analysis Subject2-V3-conv5
# Analysis Subject2-V3-fc6-conv
# Analysis Subject2-V3-fc7-conv
# Analysis Subject2-V3-fc8-conv
# Analysis Subject2-V4-conv1
# Analysis Subject2-V4-conv2
# Analysis Subject2-V4-conv3
# Analysis Subject2-V4-conv4
# Analysis Subject2-V4-conv5
# Analysis Subject2-V4-fc6-conv
# Analysis Subject2-V4-fc7-conv
# Analysis Subject2-V4-fc8-conv
# Analysis Subject2-LOC-conv1
# Analysis Subject2-LOC-conv2
# Analysis Subject2-LOC-conv3
# Analysis Subject2-LOC-conv4
# Analysis Subject2-LOC-conv5
# Analysis Subject2-LOC-fc6-conv
# Analysis Subject2-LOC-fc7-conv
# Analysis Subject2-LOC-fc8-conv
# Analysis Subject2-FFA-conv1
# Analysis Subject2-FFA-conv2
# Analysis Subject2-FFA-conv3
# Analysis Subject2-FFA-conv4
# Analysis Subject2-FFA-conv5
# Analysis Subject2-FFA-fc6-conv
# Analysis Subject2-FFA-fc7-conv
# Analysis Subject2-FFA-fc8-conv
# Analysis Subject2-PPA-conv1
# Analysis Subject2-PPA-conv2
# Analysis Subject2-PPA-conv3
# Analysis Subject2-PPA-conv4
# Analysis Subject2-PPA-conv5
# Analysis Subject2-PPA-fc6-conv
# Analysis Subject2-PPA-fc7-conv
# Analysis Subject2-PPA-fc8-conv
# Analysis Subject2-LVC-conv1
# Analysis Subject2-LVC-conv2
# Analysis Subject2-LVC-conv3
# Analysis Subject2-LVC-conv4
# Analysis Subject2-LVC-conv5
# Analysis Subject2-LVC-fc6-conv
# Analysis Subject2-LVC-fc7-conv
# Analysis Subject2-LVC-fc8-conv
# Analysis Subject2-HVC-conv1
# Analysis Subject2-HVC-conv2
# Analysis Subject2-HVC-conv3
# Analysis Subject2-HVC-conv4
# Analysis Subject2-HVC-conv5
# Analysis Subject2-HVC-fc6-conv
# Analysis Subject2-HVC-fc7-conv
# Analysis Subject2-HVC-fc8-conv
# Analysis Subject2-VC-conv1
# Analysis Subject2-VC-conv2
# Analysis Subject2-VC-conv3
# Analysis Subject2-VC-conv4
# Analysis Subject2-VC-conv5
# Analysis Subject2-VC-fc6-conv
# Analysis Subject2-VC-fc7-conv
# Analysis Subject2-VC-fc8-conv
# Analysis Subject3-V1-conv1
# Analysis Subject3-V1-conv2
# Analysis Subject3-V1-conv3
# Analysis Subject3-V1-conv4
# Analysis Subject3-V1-conv5
# Analysis Subject3-V1-fc6-conv
# Analysis Subject3-V1-fc7-conv
# Analysis Subject3-V1-fc8-conv
# Analysis Subject3-V2-conv1
# Analysis Subject3-V2-conv2
# Analysis Subject3-V2-conv3
# Analysis Subject3-V2-conv4
# Analysis Subject3-V2-conv5
# Analysis Subject3-V2-fc6-conv
# Analysis Subject3-V2-fc7-conv
# Analysis Subject3-V2-fc8-conv
# Analysis Subject3-V3-conv1
# Analysis Subject3-V3-conv2
# Analysis Subject3-V3-conv3
# Analysis Subject3-V3-conv4
# Analysis Subject3-V3-conv5
# Analysis Subject3-V3-fc6-conv
# Analysis Subject3-V3-fc7-conv
# Analysis Subject3-V3-fc8-conv
# Analysis Subject3-V4-conv1
# Analysis Subject3-V4-conv2
# Analysis Subject3-V4-conv3
# Analysis Subject3-V4-conv4
# Analysis Subject3-V4-conv5
# Analysis Subject3-V4-fc6-conv
# Analysis Subject3-V4-fc7-conv
# Analysis Subject3-V4-fc8-conv
# Analysis Subject3-LOC-conv1
# Analysis Subject3-LOC-conv2
# Analysis Subject3-LOC-conv3
# Analysis Subject3-LOC-conv4
# Analysis Subject3-LOC-conv5
# Analysis Subject3-LOC-fc6-conv
# Analysis Subject3-LOC-fc7-conv
# Analysis Subject3-LOC-fc8-conv
# Analysis Subject3-FFA-conv1
# Analysis Subject3-FFA-conv2
# Analysis Subject3-FFA-conv3
# Analysis Subject3-FFA-conv4
# Analysis Subject3-FFA-conv5
# Analysis Subject3-FFA-fc6-conv
# Analysis Subject3-FFA-fc7-conv
# Analysis Subject3-FFA-fc8-conv
# Analysis Subject3-PPA-conv1
# Analysis Subject3-PPA-conv2
# Analysis Subject3-PPA-conv3
# Analysis Subject3-PPA-conv4
# Analysis Subject3-PPA-conv5
# Analysis Subject3-PPA-fc6-conv
# Analysis Subject3-PPA-fc7-conv
# Analysis Subject3-PPA-fc8-conv
# Analysis Subject3-LVC-conv1
# Analysis Subject3-LVC-conv2
# Analysis Subject3-LVC-conv3
# Analysis Subject3-LVC-conv4
# Analysis Subject3-LVC-conv5
# Analysis Subject3-LVC-fc6-conv
# Analysis Subject3-LVC-fc7-conv
# Analysis Subject3-LVC-fc8-conv
# Analysis Subject3-HVC-conv1
# Analysis Subject3-HVC-conv2
# Analysis Subject3-HVC-conv3
# Analysis Subject3-HVC-conv4
# Analysis Subject3-HVC-conv5
# Analysis Subject3-HVC-fc6-conv
# Analysis Subject3-HVC-fc7-conv
# Analysis Subject3-HVC-fc8-conv
# Analysis Subject3-VC-conv1
# Analysis Subject3-VC-conv2
# Analysis Subject3-VC-conv3
# Analysis Subject3-VC-conv4
# Analysis Subject3-VC-conv5
# Analysis Subject3-VC-fc6-conv
# Analysis Subject3-VC-fc7-conv
# Analysis Subject3-VC-fc8-conv
# Analysis Subject4-V1-conv1
# Analysis Subject4-V1-conv2
# Analysis Subject4-V1-conv3
# Analysis Subject4-V1-conv4
# Analysis Subject4-V1-conv5
# Analysis Subject4-V1-fc6-conv
# Analysis Subject4-V1-fc7-conv
# Analysis Subject4-V1-fc8-conv
# Analysis Subject4-V2-conv1
# Analysis Subject4-V2-conv2
# Analysis Subject4-V2-conv3
# Analysis Subject4-V2-conv4
# Analysis Subject4-V2-conv5
# Analysis Subject4-V2-fc6-conv
# Analysis Subject4-V2-fc7-conv
# Analysis Subject4-V2-fc8-conv
# Analysis Subject4-V3-conv1
# Analysis Subject4-V3-conv2
# Analysis Subject4-V3-conv3
# Analysis Subject4-V3-conv4
# Analysis Subject4-V3-conv5
# Analysis Subject4-V3-fc6-conv
# Analysis Subject4-V3-fc7-conv
# Analysis Subject4-V3-fc8-conv
# Analysis Subject4-V4-conv1
# Analysis Subject4-V4-conv2
# Analysis Subject4-V4-conv3
# Analysis Subject4-V4-conv4
# Analysis Subject4-V4-conv5
# Analysis Subject4-V4-fc6-conv
# Analysis Subject4-V4-fc7-conv
# Analysis Subject4-V4-fc8-conv
# Analysis Subject4-LOC-conv1
# Analysis Subject4-LOC-conv2
# Analysis Subject4-LOC-conv3
# Analysis Subject4-LOC-conv4
# Analysis Subject4-LOC-conv5
# Analysis Subject4-LOC-fc6-conv
# Analysis Subject4-LOC-fc7-conv
# Analysis Subject4-LOC-fc8-conv
# Analysis Subject4-FFA-conv1
# Analysis Subject4-FFA-conv2
# Analysis Subject4-FFA-conv3
# Analysis Subject4-FFA-conv4
# Analysis Subject4-FFA-conv5
# Analysis Subject4-FFA-fc6-conv
# Analysis Subject4-FFA-fc7-conv
# Analysis Subject4-FFA-fc8-conv
# Analysis Subject4-PPA-conv1
# Analysis Subject4-PPA-conv2
# Analysis Subject4-PPA-conv3
# Analysis Subject4-PPA-conv4
# Analysis Subject4-PPA-conv5
# Analysis Subject4-PPA-fc6-conv
# Analysis Subject4-PPA-fc7-conv
# Analysis Subject4-PPA-fc8-conv
# Analysis Subject4-LVC-conv1
# Analysis Subject4-LVC-conv2
# Analysis Subject4-LVC-conv3
# Analysis Subject4-LVC-conv4
# Analysis Subject4-LVC-conv5
# Analysis Subject4-LVC-fc6-conv
# Analysis Subject4-LVC-fc7-conv
# Analysis Subject4-LVC-fc8-conv
# Analysis Subject4-HVC-conv1
# Analysis Subject4-HVC-conv2
# Analysis Subject4-HVC-conv3
# Analysis Subject4-HVC-conv4
# Analysis Subject4-HVC-conv5
# Analysis Subject4-HVC-fc6-conv
# Analysis Subject4-HVC-fc7-conv
# Analysis Subject4-HVC-fc8-conv
# Analysis Subject4-VC-conv1
# Analysis Subject4-VC-conv2
# Analysis Subject4-VC-conv3
# Analysis Subject4-VC-conv4
# Analysis Subject4-VC-conv5
# Analysis Subject4-VC-fc6-conv
# Analysis Subject4-VC-fc7-conv
# Analysis Subject4-VC-fc8-conv
# Analysis Subject5-V1-conv1
# Analysis Subject5-V1-conv2
# Analysis Subject5-V1-conv3
# Analysis Subject5-V1-conv4
# Analysis Subject5-V1-conv5
# Analysis Subject5-V1-fc6-conv
# Analysis Subject5-V1-fc7-conv
# Analysis Subject5-V1-fc8-conv
# Analysis Subject5-V2-conv1
# Analysis Subject5-V2-conv2
# Analysis Subject5-V2-conv3
# Analysis Subject5-V2-conv4
# Analysis Subject5-V2-conv5
# Analysis Subject5-V2-fc6-conv
# Analysis Subject5-V2-fc7-conv
# Analysis Subject5-V2-fc8-conv
# Analysis Subject5-V3-conv1
# Analysis Subject5-V3-conv2
# Analysis Subject5-V3-conv3
# Analysis Subject5-V3-conv4
# Analysis Subject5-V3-conv5
# Analysis Subject5-V3-fc6-conv
# Analysis Subject5-V3-fc7-conv
# Analysis Subject5-V3-fc8-conv
# Analysis Subject5-V4-conv1
# Analysis Subject5-V4-conv2
# Analysis Subject5-V4-conv3
# Analysis Subject5-V4-conv4
# Analysis Subject5-V4-conv5
# Analysis Subject5-V4-fc6-conv
# Analysis Subject5-V4-fc7-conv
# Analysis Subject5-V4-fc8-conv
# Analysis Subject5-LOC-conv1
# Analysis Subject5-LOC-conv2
# Analysis Subject5-LOC-conv3
# Analysis Subject5-LOC-conv4
# Analysis Subject5-LOC-conv5
# Analysis Subject5-LOC-fc6-conv
# Analysis Subject5-LOC-fc7-conv
# Analysis Subject5-LOC-fc8-conv
# Analysis Subject5-FFA-conv1
# Analysis Subject5-FFA-conv2
# Analysis Subject5-FFA-conv3
# Analysis Subject5-FFA-conv4
# Analysis Subject5-FFA-conv5
# Analysis Subject5-FFA-fc6-conv
# Analysis Subject5-FFA-fc7-conv
# Analysis Subject5-FFA-fc8-conv
# Analysis Subject5-PPA-conv1
# Analysis Subject5-PPA-conv2
# Analysis Subject5-PPA-conv3
# Analysis Subject5-PPA-conv4
# Analysis Subject5-PPA-conv5
# Analysis Subject5-PPA-fc6-conv
# Analysis Subject5-PPA-fc7-conv
# Analysis Subject5-PPA-fc8-conv
# Analysis Subject5-LVC-conv1
# Analysis Subject5-LVC-conv2
# Analysis Subject5-LVC-conv3
# Analysis Subject5-LVC-conv4
# Analysis Subject5-LVC-conv5
# Analysis Subject5-LVC-fc6-conv
# Analysis Subject5-LVC-fc7-conv
# Analysis Subject5-LVC-fc8-conv
# Analysis Subject5-HVC-conv1
# Analysis Subject5-HVC-conv2
# Analysis Subject5-HVC-conv3
# Analysis Subject5-HVC-conv4
# Analysis Subject5-HVC-conv5
# Analysis Subject5-HVC-fc6-conv
# Analysis Subject5-HVC-fc7-conv
# Analysis Subject5-HVC-fc8-conv
# Analysis Subject5-VC-conv1
# Analysis Subject5-VC-conv2
# Analysis Subject5-VC-conv3
# Analysis Subject5-VC-conv4
# Analysis Subject5-VC-conv5
# Analysis Subject5-VC-fc6-conv
# Analysis Subject5-VC-fc7-conv
# Analysis Subject5-VC-fc8-conv

# %%
df = pd.DataFrame(acc_result)

# %%
conv4 = acc_result["Subject1"]["VC"]["conv4"]["predacc_image_percept"]

# %%
df_list = []
for sbj in subject_list:
    for roi in roi_list:
        for feat in features.layers:
            for unit in range(1000):
                df_list.append({
                        "subject":sbj,
                        "ROI":roi,
                        "feature":feat,
                        "unit":unit + 1,
                        "accuracy":acc_result[sbj][roi][feat]["predacc_image_percept"][unit]
                    })

# %%
df = pd.DataFrame(df_list)

# %%
with open("./results_alex/UnitAccuracy.pkl", "wb") as f:
    pickle.dump(df, f)
